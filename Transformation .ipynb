# %%
import pandas as pd

# %%
df = pd.read_csv("Prices.csv")

# %%
df
# Out:
#    Price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110
# 5    130
# 6    150
# 7    100
# 8    105

# %% [markdown]
# # Normalization

# %%
min_Price = df.Price.min()
max_Price = df.Price.max()

# %%
min_Price
# Out:
# 100

# %%
max_Price
# Out:
# 150

# %%
df['Price_normalization_manual'] = (df.Price - min_Price ) / (max_Price - min_Price)

# %%
df
# Out:
#    Price  Price_normalization_manual
# 0    110                         0.2
# 1    105                         0.1
# 2    115                         0.3
# 3    120                         0.4
# 4    110                         0.2
# 5    130                         0.6
# 6    150                         1.0
# 7    100                         0.0
# 8    105                         0.1

# %%
from sklearn.preprocessing import MinMaxScaler
mmx = MinMaxScaler()

# %%
df['Price_normalization_sklearn'] = mmx.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Price_normalization_manual  Price_normalization_sklearn
# 0    110                         0.2                          0.2
# 1    105                         0.1                          0.1
# 2    115                         0.3                          0.3
# 3    120                         0.4                          0.4
# 4    110                         0.2                          0.2
# 5    130                         0.6                          0.6
# 6    150                         1.0                          1.0
# 7    100                         0.0                          0.0
# 8    105                         0.1                          0.1

# %% [markdown]
# # Standardization

# %%
mean_Price = df.Price.mean()
std_dof = df.Price.std(ddof=0)

# %%
df['Price_stanardization_manual'] = (df['Price'] - mean_Price) / std_dof

# %%
df
# Out:
#    Price  Price_normalization_manual  Price_normalization_sklearn  \
# 0    110                         0.2                          0.2
# 1    105                         0.1                          0.1
# 2    115                         0.3                          0.3
# 3    120                         0.4                          0.4
# 4    110                         0.2                          0.2
# 5    130                         0.6                          0.6
# 6    150                         1.0                          1.0
# 7    100                         0.0                          0.0
# 8    105                         0.1                          0.1
#
#    Price_stanardization_manual
# 0                    -0.416356
# 1                    -0.757011
# 2                    -0.075701
# 3                     0.264954
# 4                    -0.416356
# 5                     0.946264
# 6                     2.308884
# 7                    -1.097666
# 8                    -0.757011

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()

# %%
df['Price_stanardization_sklearn'] = scaler.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Price_normalization_manual  Price_normalization_sklearn  \
# 0    110                         0.2                          0.2
# 1    105                         0.1                          0.1
# 2    115                         0.3                          0.3
# 3    120                         0.4                          0.4
# 4    110                         0.2                          0.2
# 5    130                         0.6                          0.6
# 6    150                         1.0                          1.0
# 7    100                         0.0                          0.0
# 8    105                         0.1                          0.1
#
#    Price_stanardization_manual  Price_stanardization_sklearn
# 0                    -0.416356                     -0.416356
# 1                    -0.757011                     -0.757011
# 2                    -0.075701                     -0.075701
# 3                     0.264954                      0.264954
# 4                    -0.416356                     -0.416356
# 5                     0.946264                      0.946264
# 6                     2.308884                      2.308884
# 7                    -1.097666                     -1.097666
# 8                    -0.757011                     -0.757011

# %% [markdown]
# # Log transformation

# %%
import numpy as np

# %%
df['Price_log transformation_np'] = np.log1p(df[['Price']])

# %%
df
# Out:
#    Price  Price_normalization_manual  Price_normalization_sklearn  \
# 0    110                         0.2                          0.2
# 1    105                         0.1                          0.1
# 2    115                         0.3                          0.3
# 3    120                         0.4                          0.4
# 4    110                         0.2                          0.2
# 5    130                         0.6                          0.6
# 6    150                         1.0                          1.0
# 7    100                         0.0                          0.0
# 8    105                         0.1                          0.1
#
#    Price_stanardization_manual  Price_stanardization_sklearn  \
# 0                    -0.416356                     -0.416356
# 1                    -0.757011                     -0.757011
# 2                    -0.075701                     -0.075701
# 3                     0.264954                      0.264954
# 4                    -0.416356                     -0.416356
# 5                     0.946264                      0.946264
# 6                     2.308884                      2.308884
# 7                    -1.097666                     -1.097666
# 8                    -0.757011                     -0.757011
#
#    Price_log transformation_np
# 0                     4.709530
# 1                     4.663439
# 2                     4.753590
# 3                     4.795791
# 4                     4.709530
# 5                     4.875197
# 6                     5.017280
# 7                     4.615121
# 8                     4.663439

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
lt = FunctionTransformer(np.log1p)

# %%
df['Price_log transformation_sklearn'] = lt.fit_transform(df[['Price']])
df
# Out:
#    Price  Price_normalization_manual  Price_normalization_sklearn  \
# 0    110                         0.2                          0.2
# 1    105                         0.1                          0.1
# 2    115                         0.3                          0.3
# 3    120                         0.4                          0.4
# 4    110                         0.2                          0.2
# 5    130                         0.6                          0.6
# 6    150                         1.0                          1.0
# 7    100                         0.0                          0.0
# 8    105                         0.1                          0.1
#
#    Price_stanardization_manual  Price_stanardization_sklearn  \
# 0                    -0.416356                     -0.416356
# 1                    -0.757011                     -0.757011
# 2                    -0.075701                     -0.075701
# 3                     0.264954                      0.264954
# 4                    -0.416356                     -0.416356
# 5                     0.946264                      0.946264
# 6                     2.308884                      2.308884
# 7                    -1.097666                     -1.097666
# 8                    -0.757011                     -0.757011
#
#    Price_log transformation_np  Price_log transformation_sklearn
# 0                     4.709530                          4.709530
# 1                     4.663439                          4.663439
# 2                     4.753590                          4.753590
# 3                     4.795791                          4.795791
# 4                     4.709530                          4.709530
# 5                     4.875197                          4.875197
# 6                     5.017280                          5.017280
# 7                     4.615121                          4.615121
# 8                     4.663439                          4.663439

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler
robust_scaler = RobustScaler()
df['Price_Robust Scaled'] = robust_scaler.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Price_normalization_manual  Price_normalization_sklearn  \
# 0    110                         0.2                          0.2
# 1    105                         0.1                          0.1
# 2    115                         0.3                          0.3
# 3    120                         0.4                          0.4
# 4    110                         0.2                          0.2
# 5    130                         0.6                          0.6
# 6    150                         1.0                          1.0
# 7    100                         0.0                          0.0
# 8    105                         0.1                          0.1
#
#    Price_stanardization_manual  Price_stanardization_sklearn  \
# 0                    -0.416356                     -0.416356
# 1                    -0.757011                     -0.757011
# 2                    -0.075701                     -0.075701
# 3                     0.264954                      0.264954
# 4                    -0.416356                     -0.416356
# 5                     0.946264                      0.946264
# 6                     2.308884                      2.308884
# 7                    -1.097666                     -1.097666
# 8                    -0.757011                     -0.757011
#
#    Price_log transformation_np  Price_log transformation_sklearn  \
# 0                     4.709530                          4.709530
# 1                     4.663439                          4.663439
# 2                     4.753590                          4.753590
# 3                     4.795791                          4.795791
# 4                     4.709530                          4.709530
# 5                     4.875197                          4.875197
# 6                     5.017280                          5.017280
# 7                     4.615121                          4.615121
# 8                     4.663439                          4.663439
#
#    Price_Robust Scaled
# 0             0.000000
# 1            -0.333333
# 2             0.333333
# 3             0.666667
# 4             0.000000
# 5             1.333333
# 6             2.666667
# 7            -0.666667
# 8            -0.333333

# %% [markdown]
# # Max Absolute Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler
maxabs_scaler = MaxAbsScaler()
df['Price_MaxAbs Scaled'] = maxabs_scaler.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Price_normalization_manual  Price_normalization_sklearn  \
# 0    110                         0.2                          0.2
# 1    105                         0.1                          0.1
# 2    115                         0.3                          0.3
# 3    120                         0.4                          0.4
# 4    110                         0.2                          0.2
# 5    130                         0.6                          0.6
# 6    150                         1.0                          1.0
# 7    100                         0.0                          0.0
# 8    105                         0.1                          0.1
#
#    Price_stanardization_manual  Price_stanardization_sklearn  \
# 0                    -0.416356                     -0.416356
# 1                    -0.757011                     -0.757011
# 2                    -0.075701                     -0.075701
# 3                     0.264954                      0.264954
# 4                    -0.416356                     -0.416356
# 5                     0.946264                      0.946264
# 6                     2.308884                      2.308884
# 7                    -1.097666                     -1.097666
# 8                    -0.757011                     -0.757011
#
#    Price_log transformation_np  Price_log transformation_sklearn  \
# 0                     4.709530                          4.709530
# 1                     4.663439                          4.663439
# 2                     4.753590                          4.753590
# 3                     4.795791                          4.795791
# 4                     4.709530                          4.709530
# 5                     4.875197                          4.875197
# 6                     5.017280                          5.017280
# 7                     4.615121                          4.615121
# 8                     4.663439                          4.663439
#
#    Price_Robust Scaled  Price_MaxAbs Scaled
# 0             0.000000             0.733333
# 1            -0.333333             0.700000
# 2             0.333333             0.766667
# 3             0.666667             0.800000
# 4             0.000000             0.733333
# 5             1.333333             0.866667
# 6             2.666667             1.000000
# 7            -0.666667             0.666667
# 8            -0.333333             0.700000

# %%
df.to_excel('scaled prices.xlsx', index=False)
print("scaled prices.xlsx' has been generated.")
# Out:
# scaled prices.xlsx' has been generated.
